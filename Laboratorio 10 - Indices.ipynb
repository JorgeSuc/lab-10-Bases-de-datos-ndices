# %% [markdown]
# ## Laboratorio 10 - Índices
#
# #### Bienvenida
#
# Este laboratorio tiene por objetivo verificar las mejoras en el desempeño de los queries en SQL cuando se trabajan los índices adecuados.
#
# Iniciaremos cargando la extensión de python que nos permitirá interactuar con bases de datos SQLite:

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Ejercicio 1
# ===========
#
# En este ejercicio trabajaremos con el dataset [consumer complaint database](https://catalog.data.gov/dataset/consumer-complaint-database) proveniente de from data.gov:

# %%
# %sql sqlite:///complaint.db
# Out:
# 'Connected: @complaint.db'

# %% [markdown]
# Adicionalmente utilizaremos una nueva extensión para poder estudiar los tiempos de respuesta de nuestros queries:

# %%
import time

# %% [markdown]
# Iniciemos verificando de qué datos disponemos en la base de datos.
#
# Escriba a continuación los queries necesarios para estudiar de qué tablas y atributos dispone en la base de datos:

# %%
# %sql SELECT * FROM complaints LIMIT 1000;
# Out:
#  * sqlite:///complaint.db
# Done.
# [('12/30/2015', 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', '', '', 'Company chooses not to provide a public response', 'U.S. Bancorp', 'TN', '38138', '', 'N/A', 'Referral', '01/05/2016', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', '', '', 'Company chooses not to provide a public response', 'Citibank', 'NY', '13021', '', 'N/A', 'Referral', '12/23/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', '', '', '', 'Nationstar Mortgage', 'MI', '49102', '', 'N/A', 'Referral', '12/17/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Bank account or service', 'Other bank product/service', 'Account opening, closing, or management', '', '', 'Company chooses not to provide a public response', 'Wells Fargo & Company', '', '', '', 'N/A', 'Referral', '12/07/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', '', '', '', 'Nationstar Mortgage', 'FL', '33484', 'Older American', 'Consent not provided', 'Web', '01/06/2016', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', '', '', 'Company chooses not to provide a public response', 'Bank of America', 'OH', '45044', '', 'Consent not provided', 'Web', '12/22/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Debt collection', 'Other (i.e. phone, health club, etc.)', "Cont'd attempts collect debt not owed", 'Debt is not mine', '', 'Company chooses not to provide a public response', 'Solomon and Solomon, P.C.', 'NY', '14513', '', 'Consent not provided', 'Web', '12/02/2015', 'Closed with non-monetary relief', '1'),
#  ('01/05/2016', 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', '', '', '', 'Nationwide Biweekly Administration, Inc', 'AK', '99502', '', 'Consent not provided', 'Web', '01/05/2016', 'Closed with explanation', '0'),
#  ('12/02/2015', 'Debt collection', 'Payday loan', 'Taking/threatening an illegal action', 'Threatened arrest/jail if do not pay', 'I received a call from XXXX XXXX XXXX XXXX, for an unpaid payday loan. He told me that I had been contacted several times for the unpaid debt, e-mail ... (297 characters truncated) ... . I might even be put in jail. He would not give me a copy of the so called " affidavit \'\'. He told me that I would have to get a criminal attorney', ' because instead of suing me', ' the "" company \'\' is going to press charges for fraud and theft. He also yelled at me for "" crying \'\' /being emotional when he first called me. ... (5 characters truncated) ... alled me 3 times in the past month. He called from a New York number : XXXX. His name is XXXX. He also said that he would be investigating me further', ' and contacting my employers as well., Company believes it acted appropriately as authorized by contract or law,GVA Holdings', ' LLC"', 'MI', '486XX', '', 'Consent provided', 'Web', '12/02/2015'),
#  ('01/05/2016', 'Debt collection', 'Credit card', 'False statements or representation', 'Attempted to collect wrong amount', 'I received a letter by mail on XXXX XXXX 2015, stating that I owed Discover XXXX. I do n\'t know why it went into collections, since I was making pay ... (1150 characters truncated) ... then I thougt oh they took out at least XXXX from my account. But when i checked they did not. So I went to the website " XXXX \'\' to make a payment', ' but the website gave me a different amount XXXX I need help. I want to pay my debts but this law firm is making it very difficult as they are lying to me. I am a very honest person and respect the law.', None, None, None, None, None, None, None, None, '12/02/2015'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '12/02/2015'),
#  ('12/02/2015,Bank account or service,Checking account,Account opening', ' closing', ' or management"', '', '', 'Company chooses not to provide a public response', 'Bank of America', 'TX', '77083', '', 'N/A', 'Referral', '12/03/2015', 'Closed with explanation', 'Yes', '0'),
#  ('12/02/2015', 'Credit card', '', 'Billing disputes', '', '', 'Company chooses not to provide a public response', 'Citibank', 'VA', '22207', '', 'Consent not provided', 'Web', '12/02/2015', 'Closed with monetary relief', '1'),
#  ('12/22/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', '', 'Company chooses not to provide a public response', 'Citibank', 'TX', '78239', '', 'N/A', 'Postal mail', '12/28/2015', 'Closed with explanation', '1'),
#  ('12/17/2015', 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', '', '', 'Company believes it acted appropriately as authorized by contract or law', 'Select Portfolio Servicing, Inc', 'NC', '28412', 'Older American', 'N/A', 'Phone', '12/18/2015', 'Closed with explanation', '1'),
#  ('01/05/2016', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Equifax', 'MD', '208XX', '', 'Consent provided', 'Web', '01/05/2016', 'Closed with explanation', 'Yes', 'Yes', None, None, None, '1'),
#  ('12/22/2015', 'Mortgage', 'Home equity loan or line of credit', 'Loan modification,collection,foreclosure', '', '', 'Company chooses not to provide a public response', 'Citibank', 'AZ', '85248', '', 'N/A', 'Postal mail', '12/28/2015', 'Closed with explanation', '1'),
#  ('12/30/2015', 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', '', '', '', 'Seterus, Inc.', 'NY', '10598', '', 'N/A', 'Phone', '12/30/2015', 'Closed with explanation', '1'),
#  ('12/30/2015', 'Bank account or service', 'Savings account', 'Deposits and withdrawals', '', '', '', 'Apple Financial Holdings, Inc', 'NY', '10023', '', 'N/A', 'Referral', '01/05/2016', 'Closed with monetary relief', '1'),
#  ('12/22/2015', 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', '', '', '', 'Ocwen', 'FL', '33131', '', 'N/A', 'Postal mail', '12/23/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Payday loan', 'Payday loan', 'Charged bank acct wrong day or amt', 'Charged bank acct wrong day or amt', '', 'Company chooses not to provide a public response', 'Cottonwood Financial Ltd.', 'TX', '750XX', '', 'Other', 'Web', '12/28/2015', 'Closed with explanation', '1'),
#  ('01/05/2016', 'Debt collection', 'Credit card', 'Disclosure verification of debt', 'Right to dispute notice not received', '', '', 'Encore Capital Group', 'WV', '26508', '', 'Consent not provided', 'Web', '01/05/2016', 'Closed with non-monetary relief', '1'),
#  ('01/05/2016', 'Mortgage', 'Home equity loan or line of credit', 'Loan modification,collection,foreclosure', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company chooses not to provide a public response', 'Specialized Loan Servicing LLC', 'CA', '944XX', '', 'Consent provided', 'Web', '01/05/2016', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/02/2015', 'Mortgage', 'Other mortgage', 'Credit decision / Underwriting', '', '', '', 'JPMorgan Chase & Co.', 'MN', '55105', '', 'N/A', 'Referral', '12/07/2015', 'Closed with explanation', '1'),
#  ('12/30/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Information is not mine', '', '', 'Equifax', 'CA', '93534', '', 'N/A', 'Postal mail', '12/30/2015', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', '', '', 'Company believes it acted appropriately as authorized by contract or law', 'Shellpoint Partners, LLC', 'FL', '33068', '', 'Consent not provided', 'Web', '12/12/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Debt collection', 'Payday loan', 'Disclosure verification of debt', 'Not given enough info to verify debt', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('I have taken out a payday loan in the past', None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ("I explained to them that I have never gotten anything in the mail and I asked them to send me information so I could research the validity of this claim. They refused to send me information and that I could take care of it with a credit/debit card or if I did n't do that", None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('Again', None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('Company name & address : Credit Judgments XXXX XXXX XXXX XXXX', None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('12/02/2015,Debt collection,Other (i.e. phone', ' health club', ' etc.)"', "Cont'd attempts collect debt not owed", 'Debt is not mine', '', 'Company believes it acted appropriately as authorized by contract or law', 'Colony Brands, Inc.', 'NY', '14513', '', 'Consent not provided', 'Web', '12/07/2015', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Payday loan', 'Payday loan', "Charged fees or interest I didn't expect", "Charged fees or interest I didn't expect", '', '', 'Big Picture Loans, LLC', 'MD', '20712', 'Older American', 'Consent not provided', 'Web', '01/13/2016', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Public record', '', '', 'Equifax', 'FL', '32712', '', 'Consent not provided', 'Web', '12/12/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', '', '', 'Company chooses not to provide a public response', 'Bank of America', 'NY', '10011', '', 'N/A', 'Referral', '12/28/2015', 'Closed with explanation', '1'),
#  ('12/30/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', '', 'Company chooses not to provide a public response', 'Experian', 'CA', '93901', '', 'N/A', 'Postal mail', '12/30/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', '', 'Company chooses not to provide a public response', 'Experian', 'NM', '87048', '', 'N/A', 'Postal mail', '12/07/2015', 'Closed with non-monetary relief', '1'),
#  ('12/17/2015', 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', '', '', '', 'Ocwen', '', '', '', 'N/A', 'Fax', '12/18/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Debt collection', 'Other (i.e. phone, health club, etc.)', "Cont'd attempts collect debt not owed", 'Debt was paid', '', 'Company believes it acted appropriately as authorized by contract or law', 'MRS BPO, L.L.C.', 'NM', '87002', '', 'N/A', 'Referral', '12/28/2015', 'Closed with explanation', '1'),
#  ('12/30/2015', 'Debt collection', 'Credit card', 'Communication tactics', 'Frequent or repeated calls', 'THIS IS A NEW REPEAT COMPLAIN AS TODAY HAPPENED AGAIN- Ongoing ABUSE - A probably " fake \'\' Co hiding number address Name falsely representing as " ... (83 characters truncated) ... t pay DOUBLE plus {$1000.00} more of an Old Credit Card Consumer Debt with Radio Shack ( currently Bankrupt ) debt from 2004 past 10 years delinquent', ' extortion call being done ( threat to sue', ' garnish my Bank Accounts everything', ' an ABUSE ). Co calls done from XXXX XXXX XXXX caller identified as "" Supervisor \'\'', ' said Co were "" Attorneys \'\' called XXXX XXXX ( did Browse', None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('01/05/2016,Credit reporting,,Incorrect information on credit report,Account status,,Company chooses not to provide a public response,TransUnion Intermediate Holdings', ' Inc."', 'FL', '33764', '', 'N/A', 'Postal mail', '01/05/2016', 'Closed with explanation', 'Yes', 'No', None, None, None, None, '1'),
#  ('12/02/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Information is not mine', '', 'Company chooses not to provide a public response', 'Fidelity National Information Services, Inc. (FNIS)', 'FL', '32968', 'Older American', 'Consent not provided', 'Web', '12/02/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Credit reporting', '', 'Improper use of my credit report', 'Report improperly shared by CRC', '', '', 'Equifax', 'VA', '22315', '', 'N/A', 'Postal mail', '12/07/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Consumer Loan', 'Installment loan', 'Managing the loan or lease', '', '', 'Company chooses not to provide a public response', 'BB&T Financial', 'NJ', '08204', '', 'N/A', 'Referral', '12/23/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Debt collection', 'Medical', "Cont'd attempts collect debt not owed", 'Debt is not mine', '', "Company can't verify or dispute the facts in the complaint", 'Hunter Warfield, Inc.', 'AZ', '85226', '', 'Consent not provided', 'Web', '12/02/2015', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Consumer Loan', 'Installment loan', 'Managing the loan or lease', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'World Acceptance Corporation', 'IL', '617XX', '', 'Consent provided', 'Web', '12/16/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('01/05/2016', 'Debt collection', 'Credit card', 'Disclosure verification of debt', 'Not given enough info to verify debt', '', 'Company chooses not to provide a public response', 'Allied Interstate LLC', 'TX', '76054', '', 'N/A', 'Postal mail', '01/05/2016', 'Closed with non-monetary relief', '1'),
#  ('12/30/2015', 'Consumer Loan', 'Vehicle loan', 'Problems when you are unable to pay', '', '', 'Company believes it acted appropriately as authorized by contract or law', 'Nissan Motor Acceptance Corporation', 'CA', '91505', '', 'N/A', 'Postal mail', '01/13/2016', 'Closed with explanation', '1'),
#  ('12/30/2015', 'Debt collection', 'Medical', "Cont'd attempts collect debt not owed", 'Debt is not mine', None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company chooses not to provide a public response', 'CMRE Financial Services, Inc.', 'CA', '917XX', '', 'Consent provided', 'Web', '01/06/2016', 'Closed with explanation', 'Yes', 'Yes', None, None, None, '1'),
#  ('12/02/2015', 'Debt collection', 'Other (i.e. phone, health club, etc.)', "Cont'd attempts collect debt not owed", 'Debt is not mine', '', '', 'Portfolio Recovery Associates, Inc.', 'NY', '14513', '', 'Consent not provided', 'Web', '12/03/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Debt collection', 'Other (i.e. phone, health club, etc.)', "Cont'd attempts collect debt not owed", 'Debt is not mine', '', 'Company believes it acted appropriately as authorized by contract or law', 'CL Holdings, LLC', 'NJ', '08505', '', 'N/A', 'Phone', '12/23/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Debt collection', 'I do not know', 'Communication tactics', 'Threatened to take legal action', '', '', 'Lionstone Holdings Group', 'CA', '94549', '', 'Consent not provided', 'Web', '12/22/2015', 'Closed with explanation', '0'),
#  ('12/02/2015', 'Debt collection', 'I do not know', 'Communication tactics', 'Frequent or repeated calls', '', 'Company believes it acted appropriately as authorized by contract or law', 'First National Collection Bureau, Inc.', 'PA', '19136', '', 'Consent not provided', 'Web', '01/06/2016', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Consumer Loan', 'Vehicle loan', 'Managing the loan or lease', '', '', 'Company believes complaint is the result of an isolated error', 'Go Capital Holdings, LLC', 'MS', '39649', 'Servicemember', 'N/A', 'Postal mail', '12/09/2015', 'Closed with explanation', '1'),
#  ('12/30/2015', 'Debt collection', 'Mortgage', 'Disclosure verification of debt', 'Not given enough info to verify debt', '', 'Company believes it acted appropriately as authorized by contract or law', 'Quality Loan Service Corporation', 'CA', '91324', '', 'N/A', 'Postal mail', '01/05/2016', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', '', 'Company chooses not to provide a public response', 'Experian', 'TN', '38016', '', 'N/A', 'Postal mail', '12/23/2015', 'Closed with non-monetary relief', '1'),
#  ('12/02/2015', 'Consumer Loan', 'Vehicle loan', 'Managing the loan or lease', '', '', 'Company chooses not to provide a public response', 'Ally Financial Inc.', 'NY', '14513', '', 'Consent not provided', 'Web', '12/02/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Consumer Loan', 'Installment loan', 'Problems when you are unable to pay', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'NC', '284XX', 'Servicemember', 'Consent provided', 'Web', '12/08/2015', 'Closed with non-monetary relief', 'Yes', 'No', None, None, None, '1'),
#  ('12/30/2015', 'Debt collection', 'Mortgage', 'Disclosure verification of debt', 'Not given enough info to verify debt', '', 'Company believes it acted appropriately as authorized by contract or law', 'Select Portfolio Servicing, Inc', 'CA', '91324', '', 'N/A', 'Postal mail', '01/05/2016', 'Closed with explanation', '1'),
#  ('12/17/2015', 'Debt collection', 'Medical', 'Disclosure verification of debt', 'Not given enough info to verify debt', '', '', 'Alpine Credit, Inc', 'CO', '80017', '', 'Consent not provided', 'Web', '12/17/2015', 'Untimely response', '0'),
#  ('01/05/2016', 'Credit card', '', 'APR or interest rate', '', '', '', 'JPMorgan Chase & Co.', 'PA', '18058', '', 'Consent not provided', 'Web', '01/05/2016', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Credit reporting', '', "Credit reporting company's investigation", 'Problem with statement of dispute', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Equifax', 'CA', '913XX', '', 'Consent provided', 'Web', '12/12/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/12/2015', 'Credit reporting', '', "Credit reporting company's investigation", 'Problem with statement of dispute', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company chooses not to provide a public response', 'Experian', 'CA', '913XX', '', 'Consent provided', 'Web', '12/12/2015', 'Closed with non-monetary relief', 'Yes', 'No', None, None, None, '1'),
#  ('12/12/2015', 'Debt collection', 'Credit card', 'Improper contact or sharing of info', 'Talked to a third party about my debt', None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('12/12/2015,Mortgage,Conventional adjustable mortgage (ARM),Loan servicing', ' payments', ' escrow account"', '', None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'JPMorgan Chase & Co.', 'NY', '110XX', '', 'Consent provided', 'Web', '12/12/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/30/2015', 'Credit reporting', '', 'Credit monitoring or identity protection', 'Problem with fraud alerts', '', 'Company chooses not to provide a public response', 'Experian', 'GA', '30120', '', 'N/A', 'Postal mail', '12/30/2015', 'Closed with non-monetary relief', '1'),
#  ('12/17/2015', 'Debt collection', 'I do not know', 'Disclosure verification of debt', 'Not given enough info to verify debt', '', '', 'Encore Capital Group', '', '', '', 'N/A', 'Fax', '12/18/2015', 'Closed with non-monetary relief', '1'),
#  ('12/12/2015', 'Consumer Loan', 'Installment loan', 'Shopping for a loan or lease', '', '', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'PA', '15146', '', 'Consent not provided', 'Web', '12/12/2015', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Information is not mine', '', 'Company chooses not to provide a public response', 'TransUnion Intermediate Holdings, Inc.', 'CA', '93203', '', 'Consent not provided', 'Web', '12/17/2015', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Bank account or service', 'Checking account', 'Account opening, closing, or management', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'M&T Bank Corporation', 'PA', '190XX', '', 'Consent provided', 'Web', '12/12/2015', 'Closed with explanation', 'Yes', 'Yes', None, None, None, '1'),
#  ('12/22/2015', 'Bank account or service', 'Checking account', 'Problems caused by my funds being low', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Citizens Financial Group, Inc.', 'RI', '028XX', '', 'Consent provided', 'Web', '12/22/2015', 'Closed with monetary relief', 'Yes', 'No', None, None, None, '1'),
#  ('12/22/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Personal information', '', '', 'Equifax', 'IN', '46304', '', 'N/A', 'Postal mail', '12/23/2015', 'Closed with explanation', '1'),
#  ('01/05/2016', 'Consumer Loan', 'Vehicle loan', 'Managing the loan or lease', '', '', 'Company has responded to the consumer and the CFPB and chooses not to provide a public response', 'Ally Financial Inc.', 'TX', '76022', '', 'Consent not provided', 'Web', '01/05/2016', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Debt collection', 'Mortgage', "Cont'd attempts collect debt not owed", 'Debt is not mine', '', 'Company believes the complaint is the result of a misunderstanding', 'Ditech Financial LLC', 'WI', '54020', '', 'N/A', 'Postal mail', '12/07/2015', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Debt collection', 'Credit card', "Cont'd attempts collect debt not owed", 'Debt is not mine', '', '', 'Synchrony Financial', 'AL', '36054', 'Servicemember', 'Consent not provided', 'Web', '12/17/2015', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Bank account or service', 'Other bank product/service', 'Using a debit or ATM card', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company believes the complaint is the result of a misunderstanding', 'East West Bank', 'GA', '300XX', '', 'Consent provided', 'Web', '12/16/2015', 'Closed', 'Yes', 'Yes', None, None, None, '1'),
#  ('12/12/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account terms', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Equifax', 'MA', '023XX', '', 'Consent provided', 'Web', '12/12/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/22/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', '', '', 'Equifax', 'VA', '23836', '', 'N/A', 'Postal mail', '12/23/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Credit reporting', '', 'Improper use of my credit report', 'Report improperly shared by CRC', '', 'Company chooses not to provide a public response', 'TransUnion Intermediate Holdings, Inc.', 'VA', '22315', '', 'N/A', 'Postal mail', '12/07/2015', 'Closed with explanation', '1'),
#  ('12/30/2015', 'Debt collection', 'Other (i.e. phone, health club, etc.)', 'Taking/threatening an illegal action', 'Threatened arrest/jail if do not pay', '', 'Company chooses not to provide a public response', 'Regions Financial Corporation', 'GA', '30828', '', 'Consent not provided', 'Web', '01/05/2016', 'Closed with non-monetary relief', '1'),
#  ('12/02/2015', 'Credit reporting', '', 'Improper use of my credit report', 'Report improperly shared by CRC', '', '', 'Equifax', 'VA', '22315', '', 'N/A', 'Postal mail', '12/07/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Bank account or service', 'Checking account', 'Account opening, closing, or management', '', '', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'FL', '32218', '', 'Consent not provided', 'Web', '12/02/2015', 'Closed with monetary relief', '1'),
#  ('12/17/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Information is not mine', '', 'Company chooses not to provide a public response', 'Experian', 'TX', '79416', '', 'Consent not provided', 'Web', '12/17/2015', 'Closed with non-monetary relief', '1'),
#  ('12/02/2015', 'Credit reporting', '', 'Improper use of my credit report', 'Report improperly shared by CRC', '', '', 'Amex', 'VA', '22315', '', 'N/A', 'Postal mail', '12/07/2015', 'Closed with non-monetary relief', '1'),
#  ('12/12/2015', 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('12/30/2015,Credit reporting,,Incorrect information on credit report,Account terms,,Company chooses not to provide a public response,TransUnion Intermediate Holdings', ' Inc."', 'SC', '29205', '', 'Consent not provided', 'Web', '12/30/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, None, '1'),
#  ('12/30/2015', 'Debt collection', 'Medical', "Cont'd attempts collect debt not owed", 'Debt was paid', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company believes it acted appropriately as authorized by contract or law', 'Receivable Management Group, Inc. (GA)', 'FL', '346XX', '', 'Consent provided', 'Web', '01/05/2016', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/12/2015', 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', '', '', '', 'Kondaur Capital Corporation', 'TX', '77545', '', 'Consent not provided', 'Web', '12/12/2015', 'Closed with explanation', '1'),
#  ('12/17/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Information is not mine', '', '', 'Equifax', 'TX', '79416', '', 'Consent not provided', 'Web', '12/17/2015', 'Closed with explanation', '1'),
#  ('12/30/2015', 'Credit reporting', '', 'Credit monitoring or identity protection', 'Problem with fraud alerts', '', '', 'Equifax', 'GA', '30120', '', 'N/A', 'Postal mail', '12/30/2015', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', '', '', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'GA', '30316', '', 'Consent not provided', 'Web', '12/12/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Credit reporting', '', 'Credit monitoring or identity protection', 'Problem with fraud alerts', '', '', 'Equifax', 'GA', '30121', '', 'N/A', 'Referral', '12/07/2015', 'Closed with explanation', '1'),
#  ('12/30/2015', 'Credit reporting', '', 'Improper use of my credit report', 'Report improperly shared by CRC', '', 'Company chooses not to provide a public response', 'TransUnion Intermediate Holdings, Inc.', 'TX', '79912', '', 'N/A', 'Postal mail', '01/05/2016', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Consumer Loan', 'Vehicle loan', 'Problems when you are unable to pay', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'VW Credit, Inc', 'MA', '020XX', 'Servicemember', 'Consent provided', 'Web', '12/02/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/02/2015', 'Debt collection', 'Credit card', 'Improper contact or sharing of info', 'Contacted employer after asked not to', '', '', 'Portfolio Recovery Associates, Inc.', 'TX', '76264', '', 'Consent not provided', 'Web', '12/02/2015', 'Closed with non-monetary relief', '1'),
#  ('12/12/2015', 'Debt collection', 'Credit card', 'Improper contact or sharing of info', 'Talked to a third party about my debt', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Mullooly Jeffrey Rooney & Flynn', 'NY', '104XX', '', 'Consent provided', 'Web', '01/14/2016', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('01/05/2016', 'Consumer Loan', 'Installment loan', 'Problems when you are unable to pay', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', "Conn's, Inc.", 'TX', '750XX', '', 'Consent provided', 'Web', '01/08/2016', 'Closed with non-monetary relief', 'Yes', 'No', None, None, None, '1'),
#  ('12/12/2015', 'Credit card', '', 'Other', '', '', '', 'JPMorgan Chase & Co.', 'MN', '55082', '', 'Consent not provided', 'Web', '12/12/2015', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Consumer Loan', 'Vehicle loan', 'Problems when you are unable to pay', '', 'In XXXX of XXXX, I mistakenly traded my XXXX for a XXXX XXXX through XXXX XXXX in XXXX Illinois. I should have returned the vehicle and waited until  ... (1168 characters truncated) ... nts and deferments- with a late payment of {$120.00} a pop and numerous other " fees \'\' including rude and ruthless "" customer service \'\' people', ' the company who held my loan', ' Americredit ( later dissolved bought by GM Financial', " probably because they 'd taken so many people for a ride that they were being sued and no longer raking in the cash ) made sure that I was ALWAYS on the hotbed for repossession. They threatened", " cajoled and I 'm pretty sure that this company had NO interest in the car I needed", " rather they wanted that money- that was their goal and they made it clear they 'd take it every time I spoke to them. I found out later that this st ... (272 characters truncated) ... ar companies should HAVE to use banks. I am SO TIRED of hearing about the woes of the car companies : our Federal government bought it out to save it", " but GM? They are threatening to SUE me! I have no money for them! I 'm XXXX", ' I have XXXX kids', " I 've been working to get a degree ( with Fed backed loans", " why ca n't anyone get a loan for a car with bad credit for a car", " huh? People need cars! ) and I ca n't buy a home till this loan goes away. Our government is supposed to protect us from this kind of thing"),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, " huh? People need cars! ) and I ca n't buy a home till this loan goes away. Our government is supposed to protect us from this kind of thing"),
#  ('12/02/2015,Credit reporting,,Credit monitoring or identity protection,Problem with fraud alerts,,Company chooses not to provide a public response,TransUnion Intermediate Holdings', ' Inc."', 'GA', '30121', '', 'N/A', 'Referral', '12/07/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, None, " huh? People need cars! ) and I ca n't buy a home till this loan goes away. Our government is supposed to protect us from this kind of thing"),
#  ('12/22/2015', 'Credit reporting', '', 'Unable to get credit report/credit score', 'Problem getting my free annual report', None, None, None, None, None, None, None, None, None, None, " huh? People need cars! ) and I ca n't buy a home till this loan goes away. Our government is supposed to protect us from this kind of thing"),
#  ('', 'Company chooses not to provide a public response', 'Experian', 'CT', '067XX', '', 'Consent provided', 'Web', '12/22/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, " huh? People need cars! ) and I ca n't buy a home till this loan goes away. Our government is supposed to protect us from this kind of thing"),
#  ('01/05/2016', 'Debt collection', 'Credit card', "Cont'd attempts collect debt not owed", 'Debt was paid', '', '', 'Encore Capital Group', 'VA', '22152', 'Older American', 'N/A', 'Postal mail', '01/08/2016', 'Closed with explanation', '1'),
#  ('01/05/2016', 'Other financial service', 'Debt settlement', 'Fraud or scam', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Nationwide Biweekly Administration, Inc', 'CA', '945XX', '', 'Consent provided', 'Web', '02/02/2016', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/12/2015', 'Credit card', '', 'Identity theft / Fraud / Embezzlement', '', '', '', 'Synchrony Financial', 'NY', '11229', '', 'Consent not provided', 'Web', '12/17/2015', 'Closed with non-monetary relief', '1'),
#  ('01/05/2016', 'Credit card', '', 'Customer service / Customer relations', '', '', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'MD', '21239', '', 'N/A', 'Referral', '01/05/2016', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Mortgage', 'Conventional fixed mortgage', 'Settlement process and costs', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('However, the refinanced loan never got funded and we questions about it but the bank of American told us that his boss " XXXX XXXX \'\' will contact  ... (36 characters truncated) ... er -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- - XXXX XXXX', ' XXXX email below : XXXX', ' XXXX & lt ; XXXXXXXXXXXX & gt ; Wed', ' XXXX XXXX', ' 2015 at XXXX To : XXXX XXXX & lt ; XXXXXXXXXXXX & gt ; My manager is XXXX XXXX', None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('12/12/2015,Mortgage,Other mortgage,Loan modification', 'collection', 'foreclosure"', '', '', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'MA', '01876', '', 'Consent not provided', 'Web', '12/12/2015', 'Closed with explanation', 'Yes', '0'),
#  ('01/05/2016', 'Credit reporting', '', 'Incorrect information on credit report', 'Public record', None, None, None, None, None, None, None, None, None, None, '0'),
#  ('', '', 'Equifax', 'TX', '750XX', '', 'Consent provided', 'Web', '01/05/2016', 'Closed with explanation', 'Yes', 'Yes', None, None, None, '0'),
#  ('01/05/2016', 'Credit card', '', 'Closing/Cancelling account', '', '', '', 'Synchrony Financial', 'OH', '45244', '', 'N/A', 'Referral', '01/08/2016', 'Closed with explanation', '1'),
#  ('01/05/2016', 'Consumer Loan', 'Vehicle loan', 'Managing the loan or lease', '', '', 'Company believes it acted appropriately as authorized by contract or law', 'Byrider Franchising, LLC', 'IN', '47037', '', 'N/A', 'Phone', '01/08/2016', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Debt collection', 'Credit card', 'Disclosure verification of debt', 'Not given enough info to verify debt', '', '', 'Portfolio Recovery Associates, Inc.', 'TN', '37013', 'Older American', 'Consent not provided', 'Web', '12/12/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan servicing, payments, escrow account', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company chooses not to provide a public response', 'Bank of America', 'FL', '341XX', 'Older American', 'Consent provided', 'Web', '12/07/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('01/05/2016', 'Mortgage', 'Home equity loan or line of credit', 'Loan modification,collection,foreclosure', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'JPMorgan Chase & Co.', 'MI', '480XX', 'Older American', 'Consent provided', 'Web', '01/08/2016', 'Closed with explanation', 'Yes', 'Yes', None, None, None, '1'),
#  ('01/05/2016', 'Debt collection', 'Credit card', "Cont'd attempts collect debt not owed", 'Debt is not mine', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company believes it acted appropriately as authorized by contract or law', 'CFS2, Inc.', 'TX', '750XX', 'Older American', 'Consent provided', 'Web', '01/05/2016', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/12/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Equifax', 'OK', '730XX', '', 'Consent provided', 'Web', '12/12/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/02/2015', 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', '', '', 'Company chooses not to provide a public response', 'Flagstar Bank', 'NC', '28655', '', 'N/A', 'Postal mail', '12/07/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Credit reporting', '', 'Improper use of my credit report', 'Report improperly shared by CRC', '', 'Company chooses not to provide a public response', 'Experian', 'VA', '22315', '', 'N/A', 'Postal mail', '12/07/2015', 'Closed with non-monetary relief', '1'),
#  ('12/12/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', '', '', 'First Data Corporation', 'WA', '990XX', '', 'Other', 'Web', '12/12/2015', 'Closed with non-monetary relief', '1'),
#  ('12/12/2015', 'Credit card', '', 'Credit line increase/decrease', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company chooses not to provide a public response', 'Citibank', 'MO', '657XX', '', 'Consent provided', 'Web', '12/12/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/12/2015', 'Debt collection', 'Credit card', "Cont'd attempts collect debt not owed", 'Debt is not mine', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Eltman Law, P.C.', 'NY', '105XX', '', 'Consent provided', 'Web', '01/07/2016', 'Closed with explanation', 'Yes', 'Yes', None, None, None, '1'),
#  ('01/05/2016', 'Credit reporting', '', 'Incorrect information on credit report', 'Information is not mine', '', 'Company chooses not to provide a public response', 'Experian', 'FL', '32615', 'Older American', 'N/A', 'Phone', '01/05/2016', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Credit reporting', '', 'Unable to get credit report/credit score', 'Problem getting my free annual report', '', 'Company chooses not to provide a public response', 'TransUnion Intermediate Holdings, Inc.', 'NY', '10010', 'Older American', 'N/A', 'Phone', '12/23/2015', 'Closed with non-monetary relief', '1'),
#  ('12/12/2015', 'Payday loan', 'Payday loan', "Received a loan I didn't apply for", "Received a loan I didn't apply for", '', '', 'Bliksum, LLC', 'CA', '90221', '', 'Consent not provided', 'Web', '12/18/2015', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Public record', '', '', 'Equifax', 'GA', '30032', '', 'Consent not provided', 'Web', '12/12/2015', 'Closed with explanation', '1'),
#  ('01/05/2016', 'Credit card', '', 'Late fee', '', '', 'Company chooses not to provide a public response', 'Bank of America', 'TN', '37075', '', 'N/A', 'Referral', '01/08/2016', 'Closed with explanation', '1'),
#  ('01/05/2016', 'Bank account or service', 'Checking account', 'Using a debit or ATM card', '', '', 'Company chooses not to provide a public response', 'Bank of America', 'GA', '31076', '', 'N/A', 'Referral', '01/07/2016', 'Closed with monetary relief', '1'),
#  ('12/22/2015', 'Credit card', '', 'Advertising and marketing', '', '', '', 'JPMorgan Chase & Co.', 'VA', '22182', '', 'Consent not provided', 'Web', '12/22/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Money transfers', 'Domestic (US) money transfer', 'Wrong amount charged or received', '', '', '', 'Google Inc.', 'CA', '93730', '', 'Consent not provided', 'Web', '12/28/2015', 'Closed with explanation', '1'),
#  ('12/02/2015', 'Debt collection', 'Credit card', 'Disclosure verification of debt', 'Not given enough info to verify debt', '', '', 'Cavalry Investments, LLC', 'AK', '99501', '', 'Consent not provided', 'Web', '12/02/2015', 'Closed with non-monetary relief', '1'),
#  ('12/12/2015', 'Debt collection', 'Medical', "Cont'd attempts collect debt not owed", 'Debt is not mine', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Bonneville Billing and Collections', 'UT', '840XX', '', 'Consent provided', 'Web', '12/12/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/22/2015', 'Mortgage', 'Home equity loan or line of credit', 'Loan servicing, payments, escrow account', '', '', '', 'TD Bank US Holding Company', 'NJ', '08731', '', 'N/A', 'Postal mail', '12/28/2015', 'Closed with explanation', '1'),
#  ('01/05/2016', 'Debt collection', 'Other (i.e. phone, health club, etc.)', 'Disclosure verification of debt', 'Not given enough info to verify debt', '', '', 'ONLINE Information Services, Inc.', 'NH', '03456', '', 'N/A', 'Referral', '01/08/2016', 'Closed with explanation', '1'),
#  ('01/05/2016', 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', '', '', 'Company chooses not to provide a public response', 'U.S. Bancorp', 'TN', '38117', '', 'N/A', 'Referral', '01/08/2016', 'Closed with explanation', '1'),
#  ('12/12/2015', 'Mortgage', 'VA mortgage', 'Loan servicing, payments, escrow account', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'First Mortgage Corporation', 'NV', '891XX', '', 'Consent provided', 'Web', '12/12/2015', 'Untimely response', 'No', '', None, None, None, '1'),
#  ('12/22/2015', 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('The Parties have also failed to respond to the initial complaint with competent and reliable evidence that supports all facts contained within all recorded title documents that were used against my contract rights. Specifically', ' the assignment ( s ) of deed of trust to an un-verified entity', ' Notice of Default', ' Notice of Trustee Sale. No authenticated evidence has been offered by the offending Parties by any person with personal', ' first-hand knowledge of those facts. I am not in default to an unknown', None, None, None, None, None, None, None, None, None, None, '1'),
#  (',Company chooses not to provide a public response,Select Portfolio Servicing', ' Inc"', 'CA', '902XX', '', 'Consent provided', 'Web', '01/11/2016', 'Closed with explanation', 'Yes', 'No', None, None, None, None, '1'),
#  ('12/22/2015', 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', '', '', '', 'JPMorgan Chase & Co.', 'FL', '33177', '', 'Consent not provided', 'Web', '12/22/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Bank account or service', 'Checking account', 'Deposits and withdrawals', '', '', 'Company chooses not to provide a public response', 'Wells Fargo & Company', '', '', 'Older American', 'N/A', 'Fax', '12/23/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Consumer Loan', 'Vehicle loan', 'Managing the loan or lease', '', '', '', 'The Huntington National Bank', 'WV', '25302', '', 'Consent not provided', 'Web', '12/22/2015', 'Closed with explanation', '1'),
#  ('12/22/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account terms', None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('12/02/2015,Debt collection,Medical,False statements or representation,Attempted to collect wrong amount,,Company believes it acted appropriately as authorized by contract or law,Commonwealth Financial Systems', ' Inc."', 'AL', '36037', '', 'Consent not provided', 'Web', '12/02/2015', 'Closed with explanation', 'Yes', 'Yes', None, None, None, None, '1'),
# ...
#  ('', 'Company chooses not to provide a public response', 'Bank of America', 'NY', '119XX', 'Older American', 'Consent provided', 'Web', '12/21/2015', 'Closed with non-monetary relief', 'Yes', 'No', None, None, None, '1'),
#  ('12/08/2015', 'Money transfers', 'Domestic (US) money transfer', 'Other transaction issues', '', '', '', 'PayPal Holdings, Inc.', 'MA', '01844', '', 'Consent not provided', 'Web', '12/08/2015', 'Closed with explanation', '1'),
#  ('12/08/2015', 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', '', '', 'Company chooses not to provide a public response', 'Select Portfolio Servicing, Inc', 'NY', '11101', '', 'Consent not provided', 'Web', '12/08/2015', 'Closed with explanation', '1'),
#  ('12/14/2015', 'Debt collection', 'Other (i.e. phone, health club, etc.)', 'False statements or representation', 'Attempted to collect wrong amount', '', 'Company believes it acted appropriately as authorized by contract or law', 'Pressler & Pressler, LLP', 'NJ', '07108', '', 'N/A', 'Referral', '12/16/2015', 'Closed with explanation', '1'),
#  ('12/18/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', '', '', 'Equifax', 'IL', '60124', '', 'N/A', 'Referral', '12/18/2015', 'Closed with explanation', '1'),
#  ('12/08/2015', 'Mortgage', 'FHA mortgage', 'Loan modification,collection,foreclosure', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Nationstar Mortgage', 'VA', '201XX', '', 'Consent provided', 'Web', '12/08/2015', 'Closed', 'Yes', 'No', None, None, None, '1'),
#  ('12/08/2015', 'Mortgage', 'FHA mortgage', 'Loan servicing, payments, escrow account', '', 'To whom it may concern, I am writing in regards to my mortgage loan being transferred to Seterus and was given less than 2 weeks noticed and now Sete ... (363 characters truncated) ... still working on my loan. When I attempted to ask a question, the representative said " not to speak over him and to let him talk. \'\' At that point', ' I asked to speak to a manager. When I asked to speak to a manager', ' I was told that the wait would be extensive. So', ' I asked "" what is an extensive wait time. \'\' The representative said it would be 10 to 15 minutes', ' so I told the representative that I would wait. The representatives put me on hold and came back on the phone and said', " the manager will not be able to give me any information about my loan so I do n't need to wait because I just have to wait for my welcome packed in the mail. Now these are my questions", " how come the Seterus could n't give me any information about my account when I was told by XXXX that all my questions or concerns would be answered  ... (8 characters truncated) ... us since my loan was transferred over. How come the Rep was so rude and could n't get me a manager on the phone and tell me anything about my account", ' how much I owed', None, None, '1'),
#  ("The reason why this is important is because I am in the midst of selling my apt and have a potential selling date by XXXX XXXX and have an additional ... (103 characters truncated) ... to see surprising fees from Seterus. I need to know what my payments are now so that there are no surprises at the time of the closing. As a consumer", ' if my loan is transferred to Seterus', ' Seterus should have all the information ready for me when I called and not give me the run around and then say a manager is not available and that t ... (100 characters truncated) ... at are my rights as a consumer in regards to getting this information without having to wait for a welcome packets from Seterus. My other question is', None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (',,Seterus', ' Inc."', 'NY', '114XX', '', 'Consent provided', 'Web', '12/08/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, None, '1'),
#  ('12/08/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', '', 'Company chooses not to provide a public response', 'Experian', 'OH', '44103', '', 'N/A', 'Postal mail', '12/11/2015', 'Closed with explanation', '1'),
#  ('12/18/2015', 'Bank account or service', 'Checking account', 'Deposits and withdrawals', '', '', 'Company chooses not to provide a public response', 'Bank of America', 'NH', '03229', '', 'N/A', 'Phone', '12/18/2015', 'Closed with explanation', '1'),
#  ('12/18/2015', 'Debt collection', 'Medical', 'Disclosure verification of debt', 'Not given enough info to verify debt', '', '', 'Collection Information Bureau, Inc.', 'FL', '32968', '', 'Consent not provided', 'Web', '12/18/2015', 'Closed with explanation', '1'),
#  ('12/08/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', '', '', 'Equifax', 'OH', '44103', '', 'N/A', 'Postal mail', '12/11/2015', 'Closed with explanation', '1'),
#  ('12/08/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', '', 'Company chooses not to provide a public response', 'TransUnion Intermediate Holdings, Inc.', 'OH', '44103', '', 'N/A', 'Postal mail', '12/11/2015', 'Closed with explanation', '1'),
#  ('12/08/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Information is not mine', '', 'Company chooses not to provide a public response', 'CoreLogic', 'GA', '31632', '', 'N/A', 'Phone', '12/11/2015', 'Closed with explanation', '1'),
#  ('12/14/2015', 'Credit card', '', 'Delinquent account', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company chooses not to provide a public response', 'Barclays PLC', 'NY', '142XX', '', 'Consent provided', 'Web', '12/14/2015', 'Closed with monetary relief', 'Yes', 'No', None, None, None, '1'),
#  ('12/18/2015', 'Debt collection', 'Mortgage', 'Disclosure verification of debt', 'Not given enough info to verify debt', '', '', 'Selene Finance', 'MA', '02554', '', 'N/A', 'Postal mail', '12/21/2015', 'Closed with explanation', '1'),
#  ('12/14/2015', 'Debt collection', 'Credit card', "Cont'd attempts collect debt not owed", 'Debt resulted from identity theft', '', 'Company chooses not to provide a public response', 'Barclays PLC', 'TX', '77270', '', 'Consent not provided', 'Web', '12/14/2015', 'Closed with explanation', '1'),
#  ('12/14/2015', 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company chooses not to provide a public response', 'Citibank', 'MD', '212XX', '', 'Consent provided', 'Web', '12/14/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/08/2015', 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', '', '', '', 'JPMorgan Chase & Co.', 'CA', '94513', '', 'N/A', 'Referral', '12/17/2015', 'Closed with explanation', '1'),
#  ('12/18/2015', 'Credit card', '', 'Billing disputes', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company chooses not to provide a public response', 'Citibank', 'MI', '490XX', '', 'Consent provided', 'Web', '12/18/2015', 'Closed with monetary relief', 'Yes', 'Yes', None, None, None, '1'),
#  ('12/14/2015', 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', '', '', 'Company chooses not to provide a public response', 'Specialized Loan Servicing LLC', 'NC', '28262', '', 'Consent not provided', 'Web', '12/14/2015', 'Closed with explanation', '1'),
#  ('12/14/2015', 'Bank account or service', 'Checking account', 'Using a debit or ATM card', '', '', '', 'PayPal Holdings, Inc.', 'SC', '29841', 'Older American', 'N/A', 'Phone', '12/14/2015', 'Closed with monetary relief', '1'),
#  ('12/18/2015', 'Mortgage', 'Conventional fixed mortgage', 'Application, originator, mortgage broker', '', '', '', 'PHH Mortgage', 'MD', '21078', '', 'Consent not provided', 'Web', '12/18/2015', 'Closed', '1'),
#  ('12/18/2015', 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', '', '', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'FL', '33126', '', 'N/A', 'Postal mail', '12/21/2015', 'Closed with explanation', '1'),
#  ('12/18/2015', 'Debt collection', 'Credit card', "Cont'd attempts collect debt not owed", 'Debt is not mine', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Mullooly Jeffrey Rooney & Flynn', 'NY', '117XX', '', 'Consent provided', 'Web', '12/18/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/08/2015', 'Debt collection', 'Medical', "Cont'd attempts collect debt not owed", 'Debt is not mine', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company believes it acted appropriately as authorized by contract or law', 'Monterey Financial Services, Inc.', 'NJ', '073XX', 'Servicemember', 'Consent provided', 'Web', '12/08/2015', 'Closed with explanation', 'Yes', 'Yes', None, None, None, '1'),
#  ('12/08/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', 'I have sent numerous letters to XXXX XXXX XXXX , XXXX, XXXX XXXX XXXX, XXXX, WI XXXX. Requesting VALIDATION LETTERS, showing my wet ink signature, th ... (170 characters truncated) ... had with the original creditor. They are reporting this alleged debt to TransUnion, showing it in " Collections "" and in the "" Remarks \'\' section', ' it says', ' [ TransUnion ]', ' Account information disputed by consumer', None, None, None, None, None, None, '1'),
#  ('My complaint is that XXXX XXXX XXXX', ' XXXX has failed to provide any validation that I have requested in the numerous letters that I have sent them.So', None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('I have asked for the following:1 ) The original Credit Agreement that I have with XXXX XXXX XXXX ', ' XXXX XXXX with my wet ink signature on it. THEY HAVE FAILED TO PROVIDE2 ) Proof that the debt has not been "" wrote off \'\' to an insurance company ... (56 characters truncated) ... ugh an insurance claim by the original creditor. THEY HAVE FAILED TO PROVIDE3 ) Proof that this debt was not sold to their agency for a lesser amount', None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('5 ) Validation of the alleged debt', None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('THEY HAVE FAILED TO PROVIDE Since they have failed to provide any of the above information', ' yet XXXX', ' XXXX is still reporting it to TransUnion', ' along with the remark by TransUnion that it is being disputed but still meets FCRA requirements', ' I feel that this is in violation of the FCRA', ' the FDCPA and also Violation of U.S.C. title 18 Section 872', ' attempts to extort and Violation of U.S.C. title 18 Section 1341', ' 1342', None, None, None, None, None, None, None, '1'),
#  ('They have Attorney XXXX XXXX from XXXX XXXX XXXX', ' XXXX representing XXXX XXXX XXXX ', None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (',Company chooses not to provide a public response,TransUnion Intermediate Holdings', ' Inc."', 'MN', '559XX', '', 'Consent provided', 'Web', '12/08/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, None, '1'),
#  ('12/18/2015', 'Consumer Loan', 'Vehicle loan', 'Managing the loan or lease', '', '', 'Company chooses not to provide a public response', 'Ally Financial Inc.', 'MD', '20754', '', 'Consent not provided', 'Web', '12/18/2015', 'Closed with non-monetary relief', '1'),
#  ('12/18/2015', 'Student loan', 'Non-federal student loan', 'Dealing with my lender or servicer', 'Keep getting calls about my loan', '', 'Company believes the complaint is the result of a misunderstanding', 'Account Control Technology, Inc.', 'IN', '46806', '', 'Consent not provided', 'Web', '12/21/2015', 'Closed with non-monetary relief', '1'),
#  ('12/08/2015', 'Mortgage', 'Home equity loan or line of credit', 'Loan servicing, payments, escrow account', '', 'In an effort to rapidly repay the HELOC, I sent Capital One XXXX several XXXX dollars over and above the monthly interest payment. On XXXX occasions in the last 12 months, Cap One applied the payment to " this \'\' month \'s interest', ' and to "" next \'\' month \'s interest. In XXXX cases', ' they mistakenly credited my account with a couple dollars less interest and applied the rest to principle', None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '1'),
#  ('12/18/2015,Credit reporting,,Incorrect information on credit report,Public record,,Company chooses not to provide a public response,TransUnion Intermediate Holdings', ' Inc."', 'IN', '46970', '', 'N/A', 'Phone', '01/05/2016', 'Closed with explanation', 'Yes', 'No', None, None, None, None, '1'),
#  ('12/14/2015', 'Credit card', '', 'APR or interest rate', '', '', '', 'Amex', 'NC', '28277', '', 'Consent not provided', 'Web', '12/14/2015', 'Closed with monetary relief', '1'),
#  ('12/08/2015', 'Mortgage', 'Home equity loan or line of credit', 'Application, originator, mortgage broker', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'TX', '750XX', '', 'Consent provided', 'Web', '12/14/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/08/2015', 'Debt collection', 'Credit card', 'Disclosure verification of debt', 'Not given enough info to verify debt', '', 'Company chooses not to provide a public response', 'Citibank', 'NY', '14131', '', 'Consent not provided', 'Web', '12/15/2015', 'Closed with explanation', '1'),
#  ('12/14/2015', 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Credit decision / Underwriting', '', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company chooses not to provide a public response', 'Santander Bank US', 'NH', '031XX', '', 'Consent provided', 'Web', '12/14/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/08/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Information is not mine', '', '', 'MicroBilt / PRBC (formerly CL Verify)', 'GA', '31632', '', 'N/A', 'Phone', '12/15/2015', 'Closed with explanation', '1'),
#  ('12/18/2015', 'Credit card', '', 'Billing disputes', '', '', '', 'Amex', 'NJ', '07501', '', 'N/A', 'Postal mail', '12/18/2015', 'Closed with explanation', '1'),
#  ('12/08/2015', 'Credit reporting', '', 'Incorrect information on credit report', 'Public record', '', 'Company chooses not to provide a public response', 'TransUnion Intermediate Holdings, Inc.', 'NC', '27606', '', 'N/A', 'Postal mail', '12/09/2015', 'Closed with explanation', '1'),
#  ('12/18/2015', 'Debt collection', 'I do not know', 'Communication tactics', 'Frequent or repeated calls', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', 'Company believes it acted appropriately as authorized by contract or law', 'The CMI Group, Inc.', 'FL', '321XX', 'Servicemember', 'Consent provided', 'Web', '12/18/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1'),
#  ('12/14/2015', 'Debt collection', 'Other (i.e. phone, health club, etc.)', "Cont'd attempts collect debt not owed", 'Debt is not mine', None, None, None, None, None, None, None, None, None, None, '1'),
#  ('', '', 'Afni, Inc.', 'PR', '009XX', '', 'Consent provided', 'Web', '12/14/2015', 'Closed with explanation', 'Yes', 'No', None, None, None, '1')]

# %% [markdown]
# ### (a) Queries sin índices (5 puntos)
#
# Escriba a continuación un query para encontrar el producto, estado y cantidad de complaints de los cinco pares (producto, estado) con la mayor cantidad de complaints.
#
# Utilice sintaxis de una sola linea de forma que pueda utilizar `%time` para estudiar el tiempo de ejecución:

# %%
# %time %sql   SELECT State,count(*) FROM complaints GROUP BY State HAVING count(*) >1;
# Out:
#  * sqlite:///complaint.db
# Done.
# Wall time: 139 ms
# [(None, 21501),
#  ('', 562),
#  (' "" No', 2),
#  (' "" confirming my request to update my address. \'\' When I asked for said letter that I purportedly sent to change my address to said Kentucky address', 2),
#  (' 2016', 3),
#  (' Order Vacating Final Judgment ( XXXX/XXXX/XXXX )', 2),
#  (' XX/XX/XXXX', 2),
#  (' XXXX', 14),
#  (' XXXX XXXX', 11),
#  (' XXXX/XXXX/XXXX', 2),
#  (' again', 2),
#  (' however', 5),
#  (' they refused to send me any confirmation in writing that I was actually in the short sale program and continued efforts to sell the property at trustee sale. When I told them they were dual tracking', 2),
#  (' threaten with jail time and that they will see me in court', 2),
#  (' today', 3),
#  (' why different name is showing on my Social security and why i am unable to obtain my credit report and why my credit file is frozen', 3),
#  ('01/01/2016', 7),
#  ('01/02/2016', 10),
#  ('01/03/2016', 16),
#  ('01/04/2016', 30),
#  ('01/05/2016', 33),
#  ('01/06/2016', 41),
#  ('01/07/2016', 50),
#  ('01/08/2016', 33),
#  ('01/09/2016', 13),
#  ('01/10/2016', 11),
#  ('01/11/2016', 43),
#  ('01/12/2016', 50),
#  ('01/13/2016', 29),
#  ('01/14/2016', 39),
#  ('01/15/2016', 43),
#  ('01/16/2016', 14),
#  ('01/17/2016', 12),
#  ('01/18/2016', 23),
#  ('01/19/2016', 30),
#  ('01/20/2016', 45),
#  ('01/21/2016', 45),
#  ('01/22/2016', 32),
#  ('01/23/2016', 20),
#  ('01/24/2016', 12),
#  ('01/25/2016', 26),
#  ('01/26/2016', 48),
#  ('01/27/2016', 52),
#  ('01/28/2016', 59),
#  ('01/29/2016', 36),
#  ('01/30/2016', 14),
#  ('01/31/2016', 12),
#  ('02/01/2016', 39),
#  ('02/02/2016', 34),
#  ('02/03/2016', 51),
#  ('02/04/2016', 50),
#  ('02/05/2016', 37),
#  ('02/06/2016', 23),
#  ('02/07/2016', 12),
#  ('02/08/2016', 31),
#  ('02/09/2016', 44),
#  ('02/10/2016', 58),
#  ('02/11/2016', 42),
#  ('02/12/2016', 48),
#  ('02/13/2016', 14),
#  ('02/14/2016', 17),
#  ('02/15/2016', 15),
#  ('02/16/2016', 29),
#  ('02/17/2016', 46),
#  ('02/18/2016', 50),
#  ('02/19/2016', 44),
#  ('02/20/2016', 20),
#  ('02/21/2016', 17),
#  ('02/22/2016', 49),
#  ('02/23/2016', 40),
#  ('02/24/2016', 54),
#  ('02/25/2016', 39),
#  ('02/26/2016', 42),
#  ('02/27/2016', 23),
#  ('02/28/2016', 9),
#  ('02/29/2016', 34),
#  ('03/01/2016', 52),
#  ('03/02/2016', 45),
#  ('03/03/2016', 38),
#  ('03/04/2016', 33),
#  ('03/05/2016', 21),
#  ('03/06/2016', 20),
#  ('03/07/2016', 31),
#  ('03/08/2016', 53),
#  ('03/09/2016', 34),
#  ('03/10/2016', 49),
#  ('03/11/2016', 42),
#  ('03/12/2016', 17),
#  ('03/13/2016', 17),
#  ('03/14/2016', 37),
#  ('03/15/2016', 53),
#  ('03/16/2016', 47),
#  ('03/17/2016', 43),
#  ('03/18/2016', 38),
#  ('03/19/2016', 12),
#  ('03/20/2016', 11),
#  ('03/21/2016', 43),
#  ('03/22/2016', 64),
#  ('03/23/2016', 51),
#  ('03/24/2016', 42),
#  ('03/25/2016', 35),
#  ('03/26/2016', 28),
#  ('03/27/2016', 12),
#  ('03/28/2016', 43),
#  ('03/29/2016', 52),
#  ('03/30/2016', 48),
#  ('03/31/2016', 39),
#  ('04/01/2016', 43),
#  ('04/02/2016', 19),
#  ('04/03/2016', 20),
#  ('04/04/2016', 44),
#  ('04/05/2016', 54),
#  ('04/06/2016', 60),
#  ('04/07/2016', 44),
#  ('04/08/2016', 47),
#  ('04/09/2016', 24),
#  ('04/10/2016', 11),
#  ('04/11/2016', 59),
#  ('04/12/2016', 60),
#  ('04/13/2016', 40),
#  ('04/14/2016', 29),
#  ('04/15/2016', 42),
#  ('04/16/2015', 2),
#  ('04/16/2016', 9),
#  ('04/17/2016', 17),
#  ('04/18/2016', 35),
#  ('04/19/2016', 36),
#  ('04/20/2016', 45),
#  ('04/21/2016', 34),
#  ('04/22/2016', 39),
#  ('04/23/2016', 17),
#  ('04/24/2016', 15),
#  ('04/25/2016', 33),
#  ('04/26/2016', 26),
#  ('04/27/2016', 49),
#  ('04/28/2016', 40),
#  ('04/29/2016', 46),
#  ('04/30/2016', 8),
#  ('05/01/2016', 14),
#  ('05/02/2016', 39),
#  ('05/03/2016', 47),
#  ('05/04/2016', 36),
#  ('05/05/2016', 48),
#  ('05/06/2016', 33),
#  ('05/07/2016', 3),
#  ('05/08/2016', 17),
#  ('05/09/2016', 41),
#  ('05/10/2016', 40),
#  ('05/11/2016', 48),
#  ('05/12/2016', 25),
#  ('05/13/2016', 21),
#  ('05/14/2016', 18),
#  ('05/15/2016', 4),
#  ('05/16/2016', 21),
#  ('05/17/2016', 20),
#  ('05/18/2016', 25),
#  ('05/19/2016', 17),
#  ('05/20/2015', 2),
#  ('05/20/2016', 15),
#  ('05/21/2016', 12),
#  ('05/22/2016', 8),
#  ('05/23/2016', 19),
#  ('05/24/2016', 20),
#  ('05/25/2016', 9),
#  ('05/26/2016', 5),
#  ('05/27/2016', 3),
#  ('05/30/2016', 3),
#  ('05/31/2016', 6),
#  ('06/01/2016', 4),
#  ('06/02/2016', 7),
#  ('06/03/2016', 5),
#  ('06/04/2016', 2),
#  ('06/06/2016', 2),
#  ('06/07/2016', 8),
#  ('06/08/2016', 9),
#  ('06/09/2016', 5),
#  ('06/10/2016', 8),
#  ('06/11/2016', 2),
#  ('06/12/2016', 2),
#  ('06/13/2016', 8),
#  ('06/14/2016', 6),
#  ('06/15/2016', 3),
#  ('06/16/2016', 8),
#  ('06/18/2016', 4),
#  ('06/19/2016', 2),
#  ('06/20/2016', 5),
#  ('06/21/2016', 9),
#  ('06/22/2016', 4),
#  ('06/23/2016', 6),
#  ('06/24/2015', 2),
#  ('06/24/2016', 5),
#  ('06/26/2016', 3),
#  ('06/27/2016', 3),
#  ('06/28/2016', 7),
#  ('06/29/2016', 4),
#  ('06/30/2016', 5),
#  ('07/01/2016', 7),
#  ('07/03/2016', 2),
#  ('07/05/2016', 2),
#  ('07/06/2016', 6),
#  ('09/30/2015', 2),
#  ('12/02/2015', 10),
#  ('12/07/2015', 4),
#  ('12/08/2015', 25),
#  ('12/09/2015', 29),
#  ('12/12/2015', 14),
#  ('12/13/2015', 14),
#  ('12/14/2015', 28),
#  ('12/15/2015', 22),
#  ('12/16/2015', 30),
#  ('12/17/2015', 16),
#  ('12/18/2015', 30),
#  ('12/19/2015', 10),
#  ('12/20/2015', 9),
#  ('12/21/2015', 36),
#  ('12/22/2015', 20),
#  ('12/23/2015', 32),
#  ('12/24/2015', 18),
#  ('12/25/2015', 5),
#  ('12/26/2015', 9),
#  ('12/27/2015', 8),
#  ('12/28/2015', 33),
#  ('12/29/2015', 21),
#  ('12/30/2015', 25),
#  ('12/31/2015', 29),
#  ('28607', 2),
#  ('34653', 2),
#  ('44720', 2),
#  ('73157', 2),
#  ('782XX', 2),
#  ('91302', 2),
#  ('95062', 2),
#  ('98631', 2),
#  ('AE', 21),
#  ('AK', 60),
#  ('AL', 417),
#  ('AP', 13),
#  ('AR', 196),
#  ('AZ', 1095),
#  ('Bank of America', 3),
#  ('CA', 7781),
#  ('CO', 887),
#  ('CT', 591),
#  ('Citibank', 2),
#  ('Closed', 13),
#  ('Closed with explanation', 500),
#  ('Closed with monetary relief', 23),
#  ('Closed with non-monetary relief', 91),
#  ('Company believes complaint is the result of an isolated error', 2),
#  ('Company believes it acted appropriately as authorized by contract or law', 8),
#  ('Company has responded to the consumer and the CFPB and chooses not to provide a public response', 24),
#  ('Consent not provided', 2),
#  ('Consent provided', 43),
#  ('DC', 306),
#  ('DE', 265),
#  ('Equifax', 4),
#  ('Experian', 3),
#  ('FL', 5117),
#  ('GA', 2444),
#  ('GU', 2),
#  ('HI', 146),
#  ('IA', 222),
#  ('ID', 181),
#  ('IL', 1881),
#  ('IN', 523),
#  ('JPMorgan Chase & Co.', 4),
#  ('KS', 225),
#  ('KY', 352),
#  ('LA', 437),
#  ('MA', 1139),
#  ('MD', 1687),
#  ('ME', 192),
#  ('MI', 1460),
#  ('MN', 639),
#  ('MO', 577),
#  ('MS', 201),
#  ('MT', 73),
#  ('NC', 1349),
#  ('ND', 42),
#  ('NE', 170),
#  ('NH', 310),
#  ('NJ', 2130),
#  ('NM', 236),
#  ('NV', 576),
#  ('NY', 3596),
#  ('OH', 1535),
#  ('OK', 297),
#  ('OR', 582),
#  ('Ocwen', 2),
#  ('Older American', 4),
#  ('PA', 1671),
#  ('PR', 119),
#  ('PW', 2),
#  ('RI', 166),
#  ('SC', 588),
#  ('SD', 64),
#  ('Servicemember', 6),
#  ('TN', 713),
#  ('TX', 3081),
#  ('TransUnion Intermediate Holdings, Inc.', 2),
#  ('UT', 244),
#  ('Untimely response', 9),
#  ('VA', 1582),
#  ('VI', 8),
#  ('VT', 95),
#  ('WA', 1007),
#  ('WI', 581),
#  ('WV', 127),
#  ('WY', 48),
#  ('Web', 95),
#  ('Wells Fargo & Company', 2),
#  ('Yes', 4)]

# %% [markdown]
# ### (b) Queries con un índice de un solo campo (10 puntos)
#
# A continuación cree un indice de un solo campo que mejore el tiempo de respuesta de su query.
#
# Recuerde que la sintaxis para creación de queries es:
#
# > DROP INDEX IF EXISTS index_name;
# > CREATE INDEX index_name ON table(attributes);

# %%
# %sql  CREATE INDEX com_id_name ON complaints (Product,State);
# Out:
#  * sqlite:///complaint.db
# (sqlite3.OperationalError) index com_id_name already exists [SQL: 'CREATE INDEX com_id_name ON complaints (Product,State);'] (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# Ejecute nuevamente su query inicial para verificar que el tiempo de respuesta mejoró:

# %%
# %time %sql     SELECT State,count(*) FROM complaints GROUP BY State HAVING count(*) >1;
# Out:
#  * sqlite:///complaint.db
# Done.
# Wall time: 138 ms
# [(None, 21501),
#  ('', 562),
#  (' "" No', 2),
#  (' "" confirming my request to update my address. \'\' When I asked for said letter that I purportedly sent to change my address to said Kentucky address', 2),
#  (' 2016', 3),
#  (' Order Vacating Final Judgment ( XXXX/XXXX/XXXX )', 2),
#  (' XX/XX/XXXX', 2),
#  (' XXXX', 14),
#  (' XXXX XXXX', 11),
#  (' XXXX/XXXX/XXXX', 2),
#  (' again', 2),
#  (' however', 5),
#  (' they refused to send me any confirmation in writing that I was actually in the short sale program and continued efforts to sell the property at trustee sale. When I told them they were dual tracking', 2),
#  (' threaten with jail time and that they will see me in court', 2),
#  (' today', 3),
#  (' why different name is showing on my Social security and why i am unable to obtain my credit report and why my credit file is frozen', 3),
#  ('01/01/2016', 7),
#  ('01/02/2016', 10),
#  ('01/03/2016', 16),
#  ('01/04/2016', 30),
#  ('01/05/2016', 33),
#  ('01/06/2016', 41),
#  ('01/07/2016', 50),
#  ('01/08/2016', 33),
#  ('01/09/2016', 13),
#  ('01/10/2016', 11),
#  ('01/11/2016', 43),
#  ('01/12/2016', 50),
#  ('01/13/2016', 29),
#  ('01/14/2016', 39),
#  ('01/15/2016', 43),
#  ('01/16/2016', 14),
#  ('01/17/2016', 12),
#  ('01/18/2016', 23),
#  ('01/19/2016', 30),
#  ('01/20/2016', 45),
#  ('01/21/2016', 45),
#  ('01/22/2016', 32),
#  ('01/23/2016', 20),
#  ('01/24/2016', 12),
#  ('01/25/2016', 26),
#  ('01/26/2016', 48),
#  ('01/27/2016', 52),
#  ('01/28/2016', 59),
#  ('01/29/2016', 36),
#  ('01/30/2016', 14),
#  ('01/31/2016', 12),
#  ('02/01/2016', 39),
#  ('02/02/2016', 34),
#  ('02/03/2016', 51),
#  ('02/04/2016', 50),
#  ('02/05/2016', 37),
#  ('02/06/2016', 23),
#  ('02/07/2016', 12),
#  ('02/08/2016', 31),
#  ('02/09/2016', 44),
#  ('02/10/2016', 58),
#  ('02/11/2016', 42),
#  ('02/12/2016', 48),
#  ('02/13/2016', 14),
#  ('02/14/2016', 17),
#  ('02/15/2016', 15),
#  ('02/16/2016', 29),
#  ('02/17/2016', 46),
#  ('02/18/2016', 50),
#  ('02/19/2016', 44),
#  ('02/20/2016', 20),
#  ('02/21/2016', 17),
#  ('02/22/2016', 49),
#  ('02/23/2016', 40),
#  ('02/24/2016', 54),
#  ('02/25/2016', 39),
#  ('02/26/2016', 42),
#  ('02/27/2016', 23),
#  ('02/28/2016', 9),
#  ('02/29/2016', 34),
#  ('03/01/2016', 52),
#  ('03/02/2016', 45),
#  ('03/03/2016', 38),
#  ('03/04/2016', 33),
#  ('03/05/2016', 21),
#  ('03/06/2016', 20),
#  ('03/07/2016', 31),
#  ('03/08/2016', 53),
#  ('03/09/2016', 34),
#  ('03/10/2016', 49),
#  ('03/11/2016', 42),
#  ('03/12/2016', 17),
#  ('03/13/2016', 17),
#  ('03/14/2016', 37),
#  ('03/15/2016', 53),
#  ('03/16/2016', 47),
#  ('03/17/2016', 43),
#  ('03/18/2016', 38),
#  ('03/19/2016', 12),
#  ('03/20/2016', 11),
#  ('03/21/2016', 43),
#  ('03/22/2016', 64),
#  ('03/23/2016', 51),
#  ('03/24/2016', 42),
#  ('03/25/2016', 35),
#  ('03/26/2016', 28),
#  ('03/27/2016', 12),
#  ('03/28/2016', 43),
#  ('03/29/2016', 52),
#  ('03/30/2016', 48),
#  ('03/31/2016', 39),
#  ('04/01/2016', 43),
#  ('04/02/2016', 19),
#  ('04/03/2016', 20),
#  ('04/04/2016', 44),
#  ('04/05/2016', 54),
#  ('04/06/2016', 60),
#  ('04/07/2016', 44),
#  ('04/08/2016', 47),
#  ('04/09/2016', 24),
#  ('04/10/2016', 11),
#  ('04/11/2016', 59),
#  ('04/12/2016', 60),
#  ('04/13/2016', 40),
#  ('04/14/2016', 29),
#  ('04/15/2016', 42),
#  ('04/16/2015', 2),
#  ('04/16/2016', 9),
#  ('04/17/2016', 17),
#  ('04/18/2016', 35),
#  ('04/19/2016', 36),
#  ('04/20/2016', 45),
#  ('04/21/2016', 34),
#  ('04/22/2016', 39),
#  ('04/23/2016', 17),
#  ('04/24/2016', 15),
#  ('04/25/2016', 33),
#  ('04/26/2016', 26),
#  ('04/27/2016', 49),
#  ('04/28/2016', 40),
#  ('04/29/2016', 46),
#  ('04/30/2016', 8),
#  ('05/01/2016', 14),
#  ('05/02/2016', 39),
#  ('05/03/2016', 47),
#  ('05/04/2016', 36),
#  ('05/05/2016', 48),
#  ('05/06/2016', 33),
#  ('05/07/2016', 3),
#  ('05/08/2016', 17),
#  ('05/09/2016', 41),
#  ('05/10/2016', 40),
#  ('05/11/2016', 48),
#  ('05/12/2016', 25),
#  ('05/13/2016', 21),
#  ('05/14/2016', 18),
#  ('05/15/2016', 4),
#  ('05/16/2016', 21),
#  ('05/17/2016', 20),
#  ('05/18/2016', 25),
#  ('05/19/2016', 17),
#  ('05/20/2015', 2),
#  ('05/20/2016', 15),
#  ('05/21/2016', 12),
#  ('05/22/2016', 8),
#  ('05/23/2016', 19),
#  ('05/24/2016', 20),
#  ('05/25/2016', 9),
#  ('05/26/2016', 5),
#  ('05/27/2016', 3),
#  ('05/30/2016', 3),
#  ('05/31/2016', 6),
#  ('06/01/2016', 4),
#  ('06/02/2016', 7),
#  ('06/03/2016', 5),
#  ('06/04/2016', 2),
#  ('06/06/2016', 2),
#  ('06/07/2016', 8),
#  ('06/08/2016', 9),
#  ('06/09/2016', 5),
#  ('06/10/2016', 8),
#  ('06/11/2016', 2),
#  ('06/12/2016', 2),
#  ('06/13/2016', 8),
#  ('06/14/2016', 6),
#  ('06/15/2016', 3),
#  ('06/16/2016', 8),
#  ('06/18/2016', 4),
#  ('06/19/2016', 2),
#  ('06/20/2016', 5),
#  ('06/21/2016', 9),
#  ('06/22/2016', 4),
#  ('06/23/2016', 6),
#  ('06/24/2015', 2),
#  ('06/24/2016', 5),
#  ('06/26/2016', 3),
#  ('06/27/2016', 3),
#  ('06/28/2016', 7),
#  ('06/29/2016', 4),
#  ('06/30/2016', 5),
#  ('07/01/2016', 7),
#  ('07/03/2016', 2),
#  ('07/05/2016', 2),
#  ('07/06/2016', 6),
#  ('09/30/2015', 2),
#  ('12/02/2015', 10),
#  ('12/07/2015', 4),
#  ('12/08/2015', 25),
#  ('12/09/2015', 29),
#  ('12/12/2015', 14),
#  ('12/13/2015', 14),
#  ('12/14/2015', 28),
#  ('12/15/2015', 22),
#  ('12/16/2015', 30),
#  ('12/17/2015', 16),
#  ('12/18/2015', 30),
#  ('12/19/2015', 10),
#  ('12/20/2015', 9),
#  ('12/21/2015', 36),
#  ('12/22/2015', 20),
#  ('12/23/2015', 32),
#  ('12/24/2015', 18),
#  ('12/25/2015', 5),
#  ('12/26/2015', 9),
#  ('12/27/2015', 8),
#  ('12/28/2015', 33),
#  ('12/29/2015', 21),
#  ('12/30/2015', 25),
#  ('12/31/2015', 29),
#  ('28607', 2),
#  ('34653', 2),
#  ('44720', 2),
#  ('73157', 2),
#  ('782XX', 2),
#  ('91302', 2),
#  ('95062', 2),
#  ('98631', 2),
#  ('AE', 21),
#  ('AK', 60),
#  ('AL', 417),
#  ('AP', 13),
#  ('AR', 196),
#  ('AZ', 1095),
#  ('Bank of America', 3),
#  ('CA', 7781),
#  ('CO', 887),
#  ('CT', 591),
#  ('Citibank', 2),
#  ('Closed', 13),
#  ('Closed with explanation', 500),
#  ('Closed with monetary relief', 23),
#  ('Closed with non-monetary relief', 91),
#  ('Company believes complaint is the result of an isolated error', 2),
#  ('Company believes it acted appropriately as authorized by contract or law', 8),
#  ('Company has responded to the consumer and the CFPB and chooses not to provide a public response', 24),
#  ('Consent not provided', 2),
#  ('Consent provided', 43),
#  ('DC', 306),
#  ('DE', 265),
#  ('Equifax', 4),
#  ('Experian', 3),
#  ('FL', 5117),
#  ('GA', 2444),
#  ('GU', 2),
#  ('HI', 146),
#  ('IA', 222),
#  ('ID', 181),
#  ('IL', 1881),
#  ('IN', 523),
#  ('JPMorgan Chase & Co.', 4),
#  ('KS', 225),
#  ('KY', 352),
#  ('LA', 437),
#  ('MA', 1139),
#  ('MD', 1687),
#  ('ME', 192),
#  ('MI', 1460),
#  ('MN', 639),
#  ('MO', 577),
#  ('MS', 201),
#  ('MT', 73),
#  ('NC', 1349),
#  ('ND', 42),
#  ('NE', 170),
#  ('NH', 310),
#  ('NJ', 2130),
#  ('NM', 236),
#  ('NV', 576),
#  ('NY', 3596),
#  ('OH', 1535),
#  ('OK', 297),
#  ('OR', 582),
#  ('Ocwen', 2),
#  ('Older American', 4),
#  ('PA', 1671),
#  ('PR', 119),
#  ('PW', 2),
#  ('RI', 166),
#  ('SC', 588),
#  ('SD', 64),
#  ('Servicemember', 6),
#  ('TN', 713),
#  ('TX', 3081),
#  ('TransUnion Intermediate Holdings, Inc.', 2),
#  ('UT', 244),
#  ('Untimely response', 9),
#  ('VA', 1582),
#  ('VI', 8),
#  ('VT', 95),
#  ('WA', 1007),
#  ('WI', 581),
#  ('WV', 127),
#  ('WY', 48),
#  ('Web', 95),
#  ('Wells Fargo & Company', 2),
#  ('Yes', 4)]

# %% [markdown]
# ### (c) Covering indexes (10 puntos)
#
# A continuación investigue y describa qué es un _covering index_ y defina un _convering index_ que cubra el query anterior:

# %%
# %%sql
#
# -- Ingrese sus queries aquí

# %% [markdown]
# Ejecute nuevamente su query inicial para verificar que el tiempo de respuesta mejoró:

# %%
# %time %sql -- Ingrese su query aqui

# %% [markdown]
# ### (d) EXPLAIN (5 puntos)
#
# Investigue y utilice la versión SQLite de EXPLAIN para mostrar que SQLite reconoció y está utilizando su _covering index_.
#
# La sintaxis va algo así:
#
# > EXPLAIN QUERY PLAN your_query_here;

# %%
# %%sql
#
# -- Inserte su query aqui

# %% [markdown]
# Ejercicio 2
# =========
#
# Ahora veamos cómo aplicar estos conceptos a una base de datos un poco más pesada.
#
# Cargue a continuación la base de datos **ontime-2017-2018.db** utilizada durante su proyecto 1.
#
# Recuerde que puede consultar los detalles de los atributos [aqui](https://www.transtats.bts.gov/DL_SelectFields.asp?Table_ID=236).

# %%
# %sql sqlite:///ontime-2017-2018.db

# %% [markdown]
# Escriba a continuación el query necesario para mostrar los índices existentes en esta base de datos:

# %%
# %sql -- Inserte su query aquí

# %% [markdown]
# ### (a) Uso de índices en Flights (20 puntos)
#
# Ahora considere el siguiente query:
#
# ```
# SELECT f.dest
# FROM ontime f
# GROUP BY f.dest
# ```
#
# Haga uso de EXPLAIN QUERY PLAN y de `%time` para mostrar, utilizando múltiples celdas, la diferencia en el tiempo de respuesta cuando existe un índice sobre `ontime.dest`.
#
# _Nota_: Para responder a este ejercicio deberá eliminar el índice creado sobre este campo. Es probable que luego deba reiniciar la el kernel del Juyper notebook para lograr que el query plan ya no muestre al índice eliminado.

# %% [markdown]
# ### (b) Uso de covering indexes (20 puntos)
#
# El siguiente query reporta el promedio de retraso en el tiempo de llegada por cada aerolínea que vuela hacia el aeropuerto JFK:
#
# ```
# SELECT a.description, AVG(f.ArrDelay) as ArrDelayAverage
# FROM ontime f
#     LEFT JOIN unique_carriers a ON f.reporting_airline = a.code
# WHERE a.code IN (
#     SELECT DISTINCT f2.reporting_airline
#     FROM ontime f2
#     WHERE f2.dest = 'JFK'
# )
# GROUP BY a.description
# ORDER BY ArrDelayAverage DESC;
# ```
#
# Defina un covering index que mejore el desempeño del query, y muestre la respectiva mejora:

# %% [markdown]
# ### (c) Optimización de queries del proyecto (30 puntos)
#
# Utilizando las herramientas aprendidas durante este laboratorio mejore el tiempo dejecución de uno de los queries propuestos para su proyecto 1, o justique por qué no es posible mejorar ese tiempo de respuesta agregando nuevos índices.
